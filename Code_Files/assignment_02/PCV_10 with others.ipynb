# %% [markdown]
# **Question:**
# *Temporal changes in serotype distribution*

# %% [markdown]
# #IMP

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab import drive
import io
import pandas as pd
import seaborn as sns
import math

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-c743a286-5ab2-4aa4-b73f-bb4d308052d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c743a286-5ab2-4aa4-b73f-bb4d308052d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.StringIO(data['Pneumococcus_2009-Present_DSH_Casebase_Data.csv'].decode('utf-8')))

# %%
df.drop(df[df['serotype'] == 'ND'].index, inplace = True)
df.drop(df[df['serotype'] == 'NoPCV13'].index, inplace = True)
df.drop(df[df['serotype'] == 'QNS'].index, inplace = True)
df.drop(df[df['serotype'] == 'NON TYPABLE'].index, inplace = True)
df.drop(df[df['serotype'] == 'NTD'].index, inplace = True)
df.drop(df[df['year'] == 2022].index, inplace = True)

# %%
df.drop(columns=['serotype','Zila','Address','UniqueID','month','AdmDate','Age (month)','Case Definition','Outcome','Discharge Date','Hospital Duration','organism'],inplace=True)

# %%
df
# Out:
#      year
# 0    2009
# 4    2009
# 6    2009
# 8    2009
# 9    2009
# ..    ...
# 777  2021
# 778  2021
# 779  2021
# 780  2021
# 782  2021
#
# [587 rows x 1 columns]

# %% [markdown]
# percentage of PCV 10 w.r.t. year

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-e8f5e717-07d7-49a1-aea1-2a64ef399c95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8f5e717-07d7-49a1-aea1-2a64ef399c95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.read_csv(io.StringIO(data['PCV_10_with_others.csv'].decode('utf-8')))

# %%
df2
# Out:
#     year  sero_1  sero_4  sero_5  sero_6B  sero_7F  sero_9V  sero_14  \
# 0   2009       3       0       0        0        1        0        1
# 1   2010       4       0       1        0        0        0        1
# 2   2011       2       1       1        2        4        0        0
# 3   2012       5       0       3        3        0        0        1
# 4   2013       3       0       4        5        1        1        2
# 5   2014       3       0       4        3        1        2        2
# 6   2015       4       0       4        3        0        1        2
# 7   2016       2       1       0        2        2        2        2
# 8   2017       6       0       0        2        0        0        1
# 9   2018       7       0       3        0        0        1        0
# 10  2019       6       0       5        0        0        0        0
# 11  2020       6       0       2        0        0        1        0
# 12  2021       1       0       0        0        0        0        1
#
# ...

# %%
df2.drop(df[df['year'] == '2022'].index, inplace = True)
df2
# Out:
#     year  sero_1  sero_4  sero_5  sero_6B  sero_7F  sero_9V  sero_14  \
# 0   2009       3       0       0        0        1        0        1
# 1   2010       4       0       1        0        0        0        1
# 2   2011       2       1       1        2        4        0        0
# 3   2012       5       0       3        3        0        0        1
# 4   2013       3       0       4        5        1        1        2
# 5   2014       3       0       4        3        1        2        2
# 6   2015       4       0       4        3        0        1        2
# 7   2016       2       1       0        2        2        2        2
# 8   2017       6       0       0        2        0        0        1
# 9   2018       7       0       3        0        0        1        0
# 10  2019       6       0       5        0        0        0        0
# 11  2020       6       0       2        0        0        1        0
# 12  2021       1       0       0        0        0        0        1
#
# ...

# %%
df2.drop(columns=['sero_1','sero_4','sero_5','sero_6B','sero_7F','sero_9V','sero_14','sero_18C','sero_19F','sero_23F','total','others','Sum_PCV_10'],inplace=True)

# %%
plt.rcParams['figure.figsize'] = [40,20]

# %%
plt.scatter(df2["year"], df2["percentage"],s=400,c='red')
plt.grid()
plt.title("Percentage: PCV 10/all serotypes",fontsize=40,
          color="black")
# Out:
# Text(0.5, 1.0, 'Percentage: PCV 10/all serotypes')

# %%
ax=sns.scatterplot(data=df, x="serotype", y="percentage", hue="Total_case_serotype",palette="Paired",size="Total_case_serotype",sizes=(100, 600))
ax.set_title('percentage data for each serotype considering total case')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-28b15ea7ea31> in <module>
# ----> 1 ax=sns.scatterplot(data=df, x="serotype", y="percentage", hue="Total_case_serotype",palette="Paired",size="Total_case_serotype",sizes=(100, 600))
#       2 ax.set_title('percentage data for each serotype considering total case')
#       3 plt.grid()
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# PCV 10 and others

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-ed130759-f5a5-4e3b-ae95-2e0df5adbdb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed130759-f5a5-4e3b-ae95-2e0df5adbdb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df5=pd.read_csv(io.StringIO(data['PCV_10_with_others.csv'].decode('utf-8')))

# %%
df5
# Out:
#     year  sero_1  sero_4  sero_5  sero_6B  sero_7F  sero_9V  sero_14  \
# 0   2009       3       0       0        0        1        0        1
# 1   2010       4       0       1        0        0        0        1
# 2   2011       2       1       1        2        4        0        0
# 3   2012       5       0       3        3        0        0        1
# 4   2013       3       0       4        5        1        1        2
# 5   2014       3       0       4        3        1        2        2
# 6   2015       4       0       4        3        0        1        2
# 7   2016       2       1       0        2        2        2        2
# 8   2017       6       0       0        2        0        0        1
# 9   2018       7       0       3        0        0        1        0
# 10  2019       6       0       5        0        0        0        0
# 11  2020       6       0       2        0        0        1        0
# 12  2021       1       0       0        0        0        0        1
#
# ...

# %%
df5.drop(columns=['total','Sum_PCV_10','percentage'],inplace=True)

# %%
plt.rcParams['figure.figsize'] = [40,20]

# %%
fig, axes = plt.subplots(2, 1, figsize=(22, 14))

plt.title("PCV 10 with others",fontsize=30,
          color="#665191")
dn1= df['year'].value_counts().sort_index().plot(kind='bar',color='#665191',ax=axes[0])
#E1DADA
#70A1CC
dn2= df5.plot.bar(x='year',stacked=True, color=["#003f5c", "#2f4b7c", "#665191", "#a05195", "#d45087", '#f95d6a','#ff7c43','#ffa600','#C73A3A','#CB0303','#E1DADA'],ax=axes[1])
