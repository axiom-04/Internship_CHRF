# %% [markdown]
# **Question:**
# *Temporal changes in serotype distribution*

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab import drive
import io
import pandas as pd
import seaborn as sns
import math
#import sklearn as sk
from sklearn.model_selection import train_test_split
import functools

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-8985ec95-aba6-4d0e-b02a-5e11366a9041" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8985ec95-aba6-4d0e-b02a-5e11366a9041">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pneumococcus_2009-Present_DSH_Casebase_Data.csv to Pneumococcus_2009-Present_DSH_Casebase_Data.csv

# %%
df=pd.read_csv(io.StringIO(data['Pneumococcus_2009-Present_DSH_Casebase_Data.csv'].decode('utf-8')))

# %%
df.drop(df[df['serotype'] == 'ND'].index, inplace = True)
df.drop(df[df['serotype'] == 'NoPCV13'].index, inplace = True)
df.drop(df[df['serotype'] == 'QNS'].index, inplace = True)
df.drop(df[df['serotype'] == 'NTD'].index, inplace = True)

# %%
df.drop(columns=['Zila','Address','UniqueID','month','AdmDate','Age (month)','Case Definition','Outcome','Discharge Date','Hospital Duration','organism'],inplace=True)

# %%
df
# Out:
#      year serotype
# 0    2009        1
# 2    2009      NTD
# 4    2009        2
# 6    2009        1
# 8    2009       12
# ..    ...      ...
# 784  2022        5
# 785  2022        1
# 786  2022        1
# 787  2022        1
# 788  2022      23F
#
# [723 rows x 2 columns]

# %%
plt.rcParams['figure.figsize'] = [20,10]

# %% [markdown]
# **For 2009**

# %%
cond = (df.year == 2009)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# **1 2 12 14 23F**

# %% [markdown]
# **For 2010**

# %%
cond = (df.year == 2010)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# *23B 8 2 1 19A**

# %% [markdown]
# **For 2011**

# %%
cond = (df.year == 2011)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# *2 23F 18 19F 7F*

# %% [markdown]
# **For 2012**

# %%
cond = (df.year == 2012)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# *1 5 6B 12 2*

# %% [markdown]
# **For 2013**

# %%
cond = (df.year == 2013)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 19F 5 6B 6 1

# %% [markdown]
# **For 2014**

# %%
cond = (df.year == 2014)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 5 19F 1 8 6A/B

# %% [markdown]
# **For 2015**

# %%
cond = (df.year == 2015)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 1 2 20 18C 19F NTD

# %% [markdown]
# **For 2016**

# %%
cond = (df.year == 2016)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# NTD 34

# %% [markdown]
# **For 2017**

# %%
cond = (df.year == 2017)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 1 2

# %% [markdown]
# **For 2018**

# %%
cond = (df.year == 2018)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 1 8

# %% [markdown]
# **For 2019**

# %%
cond = (df.year == 2019)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 8 1 5

# %% [markdown]
# **For 2020**

# %%
cond = (df.year == 2020)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 1 2 5 18C 38

# %% [markdown]
# 1 2 NTD

# %% [markdown]
# **For 2021**

# %%
cond = (df.year == 2021)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 12A/F 6A 2 35B

# %% [markdown]
# **For 2022**

# %%
cond = (df.year == 2022)
df1=df[cond]

# %%
sns.countplot(x="year", hue="serotype", data=df1)

# %% [markdown]
# 15B 5 1 23F

# %%
cond1 = (df.year == 2012)&(df.year == 2011)

df1=df[cond1]
