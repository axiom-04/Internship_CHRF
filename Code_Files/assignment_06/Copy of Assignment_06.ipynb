# %% [markdown]
# Is there any correlation between age and serotype?

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab import drive
import io
import pandas as pd
import seaborn as sns
import math

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-107177f1-08ee-49fc-88b9-1e98e72acc20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-107177f1-08ee-49fc-88b9-1e98e72acc20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.StringIO(data['timeframe.csv'].decode('utf-8')))

# %%
df.drop(df[df['serotype'] == 'ND'].index, inplace = True)
df.drop(df[df['serotype'] == 'NoPCV13'].index, inplace = True)
df.drop(df[df['serotype'] == 'QNS'].index, inplace = True)
df.drop(df[df['serotype'] == 'NTD'].index, inplace = True)
df.drop(df[df['serotype'] == 'NON TYPABLE'].index, inplace = True)
df.drop(df[df['serotype'] == '12'].index, inplace = True)
df.drop(df[df['serotype'] == '23B'].index, inplace = True)
df.drop(df[df['serotype'] == '35F'].index, inplace = True)
df.drop(df[df['serotype'] == '63'].index, inplace = True)
df.drop(df[df['serotype'] == '42'].index, inplace = True)
df.drop(df[df['serotype'] == '4'].index, inplace = True)
df.drop(df[df['serotype'] == '11F'].index, inplace = True)
df.drop(df[df['serotype'] == '7A/F'].index, inplace = True)
df.drop(df[df['serotype'] == '29'].index, inplace = True)
df.drop(df[df['serotype'] == '6D'].index, inplace = True)
df.drop(df[df['serotype'] == '7F/A'].index, inplace = True)
df.drop(df[df['serotype'] == '15C'].index, inplace = True)
df.drop(df[df['serotype'] == '22A/F'].index, inplace = True)
df.drop(df[df['serotype'] == '34'].index, inplace = True)
df.drop(df[df['serotype'] == '15B/C'].index, inplace = True)
df.drop(df[df['serotype'] == '11A/D'].index, inplace = True)
df.drop(df[df['serotype'] == '10B'].index, inplace = True)
df.drop(df[df['serotype'] == '3'].index, inplace = True)
df.drop(df[df['serotype'] == '39'].index, inplace = True)
df.drop(df[df['serotype'] == '40'].index, inplace = True)
df.drop(df[df['serotype'] == '12A/F'].index, inplace = True)
df.drop(df[df['serotype'] == '15A/F'].index, inplace = True)
df.drop(df[df['serotype'] == '12F/A'].index, inplace = True)
df.drop(df[df['serotype'] == '9L'].index, inplace = True)
df.drop(df[df['serotype'] == '7B/C'].index, inplace = True)
df.drop(df[df['serotype'] == '10A/B'].index, inplace = True)
df.drop(df[df['serotype'] == '19B'].index, inplace = True)
df.drop(df[df['serotype'] == '22F/A'].index, inplace = True)
df.drop(df[df['serotype'] == '19a'].index, inplace = True)
df.drop(df[df['serotype'] == '23A'].index, inplace = True)
df.drop(df[df['serotype'] == '24F'].index, inplace = True)
df.drop(df[df['serotype'] == '48'].index, inplace = True)
df.drop(df[df['serotype'] == '27'].index, inplace = True)

# %%
#df.drop(columns=['Outcome','year','Zila','Address','UniqueID','month','AdmDate','Case Definition','Hospital Duration','Discharge Date','organism'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3a1a5388a83f> in <module>
# ----> 1 df.drop(columns=['Outcome','year','Zila','Address','UniqueID','month','AdmDate','Case Definition','Hospital Duration','Discharge Date','organism'],inplace=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#      Age (month) serotype Timeframe
# 0             21        1       pre
# 4              3        2       pre
# 6             69        1       pre
# 9              6       14       pre
# 11            72      23F       pre
# ..           ...      ...       ...
# 784            1        5      post
# 785           80        1      post
# 786           84        1      post
# 787           75        1      post
# 788           20      23F      post
#
# [498 rows x 3 columns]

# %%
plt.rcParams['figure.figsize'] = [40,20]

# %%
ax = sns.boxplot(x="serotype", y="Age (month)", data=df)

# %%
sns.set(font_scale = 2.5)
ax = sns.boxplot(data=df, x="serotype", y="Age (month)", hue="Timeframe")
#ax.set_xlabel("X Label",fontsize=30)
#ax.set_ylabel("Y Label",fontsize=20)
#ax.tick_params(labelsize=5)
plt.xticks(rotation = 45)
plt.grid()
plt.show()
