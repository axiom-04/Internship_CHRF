# %% [markdown]
# Ques:
# Which serotypes are most likely to cause meningitis?

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from google.colab import drive
import io
import pandas as pd
import seaborn as sns
import math
#import sklearn as sk
from sklearn.model_selection import train_test_split

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-4e9bc3f3-62c1-4a20-903d-41d384b734d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e9bc3f3-62c1-4a20-903d-41d384b734d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.StringIO(data['parcentage_data2.csv'].decode('utf-8')))

# %%
df
# Out:
#     Unnamed: 0 serotype  Meningitis  Total_case_serotype  percentage
# 0            0        1          19                   55   34.545455
# 1            1      10A           3                    5   60.000000
# 2            2    10A/B           1                    1  100.000000
# 3            3      10B           0                    2    0.000000
# 4            4      10F           3                    7   42.857143
# ..         ...      ...         ...                  ...         ...
# 67          67       7F           6                    9   66.666667
# 68          68     7F/A           1                    2   50.000000
# 69          69        8          22                   31   70.967742
# 70          70       9L           0                    1    0.000000
# 71          71       9V           2                    8   25.000000
#
# [72 rows x 5 columns]

# %% [markdown]
# Applying threshold

# %%
#df = df[df['Total_case_serotype'] > 3]

# %%
len(df['Total_case_serotype'])
# Out:
# 72

# %%
df=df.sort_values('percentage')

# %%
df
# Out:
#     Unnamed: 0 serotype  Meningitis  Total_case_serotype  percentage
# 47          47      35F           0                    1         0.0
# 33          33      22F           0                    4         0.0
# 70          70       9L           0                    1         0.0
# 22          22      17F           0                    5         0.0
# 39          39      24F           0                    1         0.0
# ..         ...      ...         ...                  ...         ...
# 64          64     7A/F           2                    2       100.0
# 2            2    10A/B           1                    1       100.0
# 40          40       27           1                    1       100.0
# 34          34    22F/A           1                    1       100.0
# 12          12    12F/A           1                    1       100.0
#
# [72 rows x 5 columns]

# %% [markdown]
#  **after sorting serotypes with respect to percentage**

# %%
plt.rcParams['figure.figsize'] = [40,20]

# %%
plt.scatter(df["serotype"], df["percentage"],s=400,c='red')
plt.grid()

# %% [markdown]
# **Considering the no of samples**

# %%
#df['Total_case_serotype'] = pd.cut(df["Total_case_serotype"], bins=7, labels=[f'level {i}' for i in range(1, 8)])

# %%
ax=sns.scatterplot(data=df, x="serotype", y="percentage", hue="Total_case_serotype",palette="flare",size="Total_case_serotype",sizes=(200, 1000))
plt.grid()

# %%
#sns.set(font_scale=1)
ax=sns.scatterplot(data=df, x="serotype", y="percentage", hue="Total_case_serotype",palette="Paired",size="Total_case_serotype",sizes=(200, 1200))
ax.set_title('percentage data for each serotype considering total case')
plt.grid()
plt.xlabel('serotype', fontsize=20);
plt.ylabel('percentage', fontsize=20);
plt.title('percentage data for each serotype considering total case', fontsize=20)
# Out:
# Text(0.5, 1.0, 'percentage data for each serotype considering total case')

# %%
palette_2 = sns.color_palette(["#fbf8cc","#fde4cf","#ffcfd2","#f1c0e8","#cfbaf0","#a3c4f3","#90dbf4","#8eecf5","#98f5e1","#b9fbc0"])
palette_2
# Out:
# [(0.984313725490196, 0.9725490196078431, 0.8),
#  (0.9921568627450981, 0.8941176470588236, 0.8117647058823529),
#  (1.0, 0.8117647058823529, 0.8235294117647058),
#  (0.9450980392156862, 0.7529411764705882, 0.9098039215686274),
#  (0.8117647058823529, 0.7294117647058823, 0.9411764705882353),
#  (0.6392156862745098, 0.7686274509803922, 0.9529411764705882),
#  (0.5647058823529412, 0.8588235294117647, 0.9568627450980393),
#  (0.5568627450980392, 0.9254901960784314, 0.9607843137254902),
#  (0.596078431372549, 0.9607843137254902, 0.8823529411764706),
#  (0.7254901960784313, 0.984313725490196, 0.7529411764705882)]

# %%
ax=sns.scatterplot(data=df, x="serotype", y="percentage", hue="Total_case_serotype",palette="flare",size="Total_case_serotype",sizes=(10, 600))
ax.set_title('meningitis')
plt.grid()

# %% [markdown]
# **Highlighting serotypes of PCV-10**

# %%
#df = df.assign(Vaccine=df['serotype']=='1')
#df = df.assign(Vaccine=df['serotype']=='4')
#df = df.assign(Vaccine=df['serotype']=='5')
#,'4','5','6B','7F','9V','14','18C','19F','23F','3','6A','19A'
#df
